# %% [markdown]
# # Construction of the BDY

# %% [markdown]
# __tool__ : MKBDYDTA (in $SCRATCHDIR/DEV or https://servforge.legi.grenoble-inp.fr/svn/wg-drakkar/MKBDYDTA)

# %% [markdown]
# ## Namelist
#
# 2 BDY : North & South
#
#  - South : nbdyind = 2, nbdybeg ? nbdyend ?

# %%
# %matplotlib inline
import xarray as xr
import numpy as npy

file="/media/extra/DATA/NATL12/BDYS.nc"
ds=xr.open_dataset(file)
bathy=ds.Bathymetry
bathy.plot()

npy.argwhere(bathy.values>10)
# Out:
# /home/albert/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:10: RuntimeWarning: invalid value encountered in greater
# array([[   0,  699],
#        [   0,  700],
#        [   0,  701],
#        ...,
#        [   0, 1324],
#        [   0, 1325],
#        [   0, 1326]])

# %% [markdown]
#  => nbdybeg = 699, nbdyend = 1326

# %% [markdown]
#  - North : nbdyind = jpjglo - 2 = 1566, nbdybeg ? nbdyend ?

# %%
file="/media/extra/DATA/NATL12/BDYN.nc"
ds=xr.open_dataset(file)
bathy=ds.Bathymetry
bathy.plot()

npy.argwhere(bathy.values>10)
# Out:
# /home/albert/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:6: RuntimeWarning: invalid value encountered in greater
# array([[   0,  501],
#        [   0,  502],
#        [   0,  503],
#        ...,
#        [   0, 1435],
#        [   0, 1436],
#        [   0, 1437]])

# %% [markdown]
#  => nbdybeg = 501, nbdyend = 1437
